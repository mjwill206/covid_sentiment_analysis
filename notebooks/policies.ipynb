# %%
import pandas as pd
df = pd.read_csv('./policies.csv', index_col = 'Location')

# %%
df.head()
# Out:
#                 Status of Reopening Stay at Home Order  \
# Location
# AL                           Paused             Lifted
# AK        Proceeding with Reopening             Lifted
# AZ         New Restrictions Imposed             Lifted
# AR                           Paused                  -
# CA         New Restrictions Imposed          Statewide
#
#          Mandatory Quarantine for Travelers  \
# Location
# AL                                        -
# AK                            All Travelers
# AZ                                   Lifted
# AR                                   Lifted
# CA                                        -
#
#                             Non-Essential Business Closures  \
# Location
# AL        All Non-Essential Businesses Permitted to Reop...
# AK         All Non-Essential Businesses Permitted to Reopen
# AZ                          New Business Closures or Limits
# AR                                                        -
# ...

# %%
df.to_csv('./policies.csv')
